# %% [markdown]
# 使用Qwen模型的api

# %%
from langchain_community.llms import tongyi

key = "sk-c3273cef5a394ce59c8a6c477d0bdfa4"
model = 'qwen3-vl-flash'
llm = tongyi.Tongyi(api_key=key)


## 调用
response = llm("请介绍一下你自己")
response
# Out:
# '你好！😊 我是通义千问（Qwen），阿里巴巴集团旗下的超大规模语言模型。我能够理解并生成多种语言的文本，比如中文、英文、法语、西班牙语、葡萄牙语、俄语、阿拉伯语、日语、韩语、越南语、泰语、印尼语等，支持国际化交流。\n\n我的能力包括但不限于：\n🔹 **回答问题**：无论是常识、科学、历史、文化，还是日常生活中的疑问，我都会尽力提供准确、清晰、有依据的回答；\n🔹 **创作文字**：写故事、写公文、写邮件、写剧本、逻辑推理、编程，甚至写诗歌或歌词，我都可以尝试；\n🔹 **逻辑与数学**：能进行多步推理、解决数学题、分析数据逻辑；\n🔹 **编程辅助**：支持多种主流编程语言，可解释代码、调试建议、生成函数或完整项目结构；\n🔹 **多模态理解（部分版本）**：在通义万相、通义听悟等兄弟模型配合下，还能处理图像、语音、视频等多类型信息（当前对话中我主要以文本形式与你交互）。\n\n我注重事实准确性、价值观正向、尊重多元文化，并严格遵守中国及国际相关法律法规，不生成违法、有害、歧视性或侵犯隐私的内容。\n\n需要提醒的是：虽然我努力做到可靠，但我的知识截止于2024年10月，且无法实时联网获取最新信息（除非你使用接入实时搜索的版本）。对于专业领域（如医疗、法律、金融）的问题，我会建议你咨询持证专业人士。\n\n很高兴认识你！✨ 有什么问题、想法或需要帮忙的地方，随时告诉我吧～ 🌟'

# %%
print(llm.invoke("请介绍一下你自己"))
# Out:
# 你好！😊 我是通义千问（Qwen），由通义实验室研发的超大规模语言模型。我能够理解并生成多种语言（如中文、英文、法语、西班牙语、葡萄牙语、俄语、阿拉伯语、日语、韩语、越南语、泰语、印尼语等），支持广泛的应用场景，包括：
#
# 🔹 **问答与知识解答**：无论是科学常识、历史人文、技术原理，还是生活小窍门，我都会尽力提供准确、清晰、有依据的回答；
# 🔹 **创作与表达**：写故事、写公文、写邮件、写剧本、逻辑推理、编程，甚至写诗歌或歌词，我都可以协助；
# 🔹 **多轮对话与角色扮演**：我能记住上下文，进行连贯深入的交流，也支持温和、专业、幽默等不同风格的互动；
# 🔹 **逻辑与计算**：具备基础的数学推理、代码理解与生成能力（支持Python、Java、C++、JavaScript等多种语言）；
# 🔹 **文件处理**：可阅读并分析你上传的PDF、Word、Excel、PPT等文档（在支持该功能的平台/APP中），帮你提炼重点、总结内容、解答问题。
#
# 需要说明的是：
# ✅ 我不联网（除非你使用的平台明确开启“联网搜索”功能），因此我的知识截止于2024年10月；
# ✅ 我不会主动收集或存储你的个人信息，注重隐私保护；
# ✅ 我没有情感和意识，但会以尊重、友善、负责任的态度与你交流。
#
# 如果你有任何问题、想法或需要帮助——比如学习辅导、工作提效、创意启发，甚至只是想聊聊天气或哲学——我都很乐意陪伴你一起探索 🌟
# 现在，有什么我可以帮你的吗？ 😊

# %%
## 智谱ai

zhipuai_api_key = "4c436c37955741c290d3b97fce80fbb9.R6C2peSTtc9Stc8N"

from langchain_community.chat_models import ChatZhipuAI
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

import os

os.environ["ZHIPUAI_API_KEY"] = zhipuai_api_key     

chat = ChatZhipuAI(
    model="glm-4",
    temperature=0.5,
)

messages = [
    AIMessage(content="Hi."),
    SystemMessage(content="你是一个助手，请用中文回复我"),
    HumanMessage(content="夏天适合吃什么水果"),
]
response = chat.invoke(messages)
print(response.content)
print(response.response_metadata)
print(response)
# Out:
# d:\Anaconda\envs\agent_env\Lib\site-packages\jwt\api_jwt.py:147: InsecureKeyLengthWarning: The HMAC key is 16 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   return self._jws.encode(
# 夏天适合吃的水果有很多，它们不仅能消暑解渴，还能提供丰富的营养。以下是一些推荐：
#
# 1. **西瓜**：夏季的代表性水果，含水量高，能迅速补充水分，帮助消暑。
# 2. **哈密瓜**：香甜可口，富含维生素A和C，有助于维持皮肤健康。
# 3. **桃子**：汁多味甜，含有多种维生素和矿物质，有助于补充夏季流失的营养。
# 4. **荔枝**：味道甜美，含有丰富的维生素C和抗氧化物质，但要注意适量食用，因为糖分较高。
# 5. **芒果**：香甜多汁，富含维生素A和C，对眼睛和皮肤健康有益。
# 6. **葡萄**：水分充足，含有多种抗氧化物质，有助于抵抗夏季紫外线对皮肤的伤害。
# 7. **草莓**：低热量，富含维生素C和抗氧化物质，有助于美白和增强免疫力。
# 8. **菠萝**：含有菠萝蛋白酶，有助于消化，适合夏季食欲不振时食用。
# 9. **蓝莓**：富含抗氧化物质，有助于保护视力，增强免疫力。
# 10. **猕猴桃**：含有丰富的维生素C和膳食纤维，有助于促进消化和增强免疫力。
#
# 这些水果不仅美味，还能帮助你在炎热的夏季保持健康和活力。记得适量食用，享受夏日的清凉！
# {'token_usage': {'completion_tokens': 266, 'prompt_tokens': 31, 'total_tokens': 297}, 'model_name': 'glm-4', 'finish_reason': 'stop'}
# ...

# %%
## ollama本地服务
from langchain_ollama.llms import OllamaLLM
model = OllamaLLM(model="deepseek-r1:1.5b")
res = model.invoke("请介绍一下你自己")
print(res)
# Out:
# 我是DeepSeek-R1，一个由深度求索公司开发的智能助手，我会尽我所能为您提供帮助。
